# %% [markdown]
# Q1. How do you comment code in Python? What are the different types of comments?

# %%
#ANSWER: Comment is used to understand the code in a easiest way compliler will ignore this comments so we can use it as heading or for explaining the codes
"#" #This is a single line comment in python
'''This is a multiple line comment we can write multiple line in this comment'''
"""This is also a Multiple line comment we can use single or double quots for comments"""

# %% [markdown]
# Q2. What are variables in Python? How do you declare and assign values to variables?

# %%
'Answer:' 'Variable is used to store the value it acts like a container'
"""Declaring and assining variable"""
var=10
var1="Pwskills"
#The Symbol "=" is used to assign value to a variable

# %% [markdown]
# Q3. How do you convert one data type to another in Python?<br>
# Answer: we can convert one data type to anther by using it's function<br>
# Example:

# %%
integer=10
float_number = float(integer) #we have converted integer into floating point number
print(float_number)
Str1="123"
integer_number=int(Str1)#we have converted string into a integer
print(integer_number)

# %% [markdown]
# Q4. How do you write and execute a Python script from the command line?

# %% [markdown]
# Answer:Open a text editor and create a new file. You can use any text editor of your choice, such as Notepad, Sublime Text
# Write your Python code in the text editor. For example, let's say you want to create a script that prints "Hello, World!":
# Save the file with a .py extension. For example, you can save it as hello.py.
# Open the command line or terminal on your operating system. The method for opening the command line varies depending on your operating system. Here are some common ways to do it
# Now Open the command terminal and navigate the document where you saved nowexecute the Python script by typing python followed by the name of your script file. In our example, you would run
# Eg:python hello.py
# ress Enter now you will get expected output "Hello, World!"

# %% [markdown]
# Q5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].

# %%
my_list = [1, 2, 3, 4, 5]
L=my_list[1:3]
print(L)

# %% [markdown]
# Q8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable
# belong to?

# %%
price=9.99
type(price) #this variable belogs to float data type

# %% [markdown]
# Q9. Create a variable named name and assign your full name to it as a string. How would you print the
# value of this variable?

# %%
name="Syed Rahman Ur Lateef"
print(name) #using print function we can print the value of any variable

# %% [markdown]
# Q10. Given the string "Hello, World!", extract the substring "World".

# %%
Str="Hello, World!"
Substring=Str[7:12]
print(Substring)

# %% [markdown]
# Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are
# currently a student or not.

# %%
is_student=True
if is_student:
    print("Your are Currently a Student")
else:
    print("Your not a Student")
